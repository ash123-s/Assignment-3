# %%
import pandas as pd
d=pd.read_csv(r"/mobile_cleaned-1549119762886.csv")
d
# Out:
#      sim_type  aperture  gpu_rank  ...  battery_capacity  processor_rank  is_liked
# 0           0        12        55  ...              2000             125         1
# 1           0         1        55  ...              2000             165         1
# 2           0         9        55  ...              2500             164         0
# 3           0         8        55  ...              3000             165         1
# 4           1         1        55  ...              3000             165         0
# ..        ...       ...       ...  ...               ...             ...       ...
# 104         3        10        14  ...              3410               8         1
# 105         0         5         3  ...              3600             101         1
# 106         3        10         6  ...              2750               1         1
# 107         3        10        12  ...              1810               7         1
# 108         2         8         3  ...              3000               2         0
#
# [109 rows x 40 columns]

# %%
import matplotlib.pyplot as plt
plt.plot(d)
# Out:
# [<matplotlib.lines.Line2D at 0x7fa6d5b9f160>,
#  <matplotlib.lines.Line2D at 0x7fa6d5b9f278>,
#  <matplotlib.lines.Line2D at 0x7fa6d5b9f3c8>,
#  <matplotlib.lines.Line2D at 0x7fa6d5b9f518>,
#  <matplotlib.lines.Line2D at 0x7fa6d5b9f668>,
#  <matplotlib.lines.Line2D at 0x7fa6d5b9f7b8>,
#  <matplotlib.lines.Line2D at 0x7fa6d5b9f908>,
#  <matplotlib.lines.Line2D at 0x7fa6d5b9fa58>,
#  <matplotlib.lines.Line2D at 0x7fa6d5b9fba8>,
#  <matplotlib.lines.Line2D at 0x7fa6d5b9fcf8>,
#  <matplotlib.lines.Line2D at 0x7fa6d5b80748>,
#  <matplotlib.lines.Line2D at 0x7fa6d5b9ff60>,
#  <matplotlib.lines.Line2D at 0x7fa6d5ba50f0>,
#  <matplotlib.lines.Line2D at 0x7fa6d5ba5240>,
#  <matplotlib.lines.Line2D at 0x7fa6d5ba5390>,
#  <matplotlib.lines.Line2D at 0x7fa6d5ba54e0>,
#  <matplotlib.lines.Line2D at 0x7fa6d5ba5630>,
#  <matplotlib.lines.Line2D at 0x7fa6d5ba5780>,
#  <matplotlib.lines.Line2D at 0x7fa6d5ba58d0>,
#  <matplotlib.lines.Line2D at 0x7fa6d5ba5a20>,
#  <matplotlib.lines.Line2D at 0x7fa6d5ba5b70>,
#  <matplotlib.lines.Line2D at 0x7fa6d5ba5cc0>,
#  <matplotlib.lines.Line2D at 0x7fa6d5ba5e10>,
#  <matplotlib.lines.Line2D at 0x7fa6d5ba5f60>,
#  <matplotlib.lines.Line2D at 0x7fa6d5bac0f0>,
#  <matplotlib.lines.Line2D at 0x7fa6d5bac240>,
#  <matplotlib.lines.Line2D at 0x7fa6d5bac390>,
#  <matplotlib.lines.Line2D at 0x7fa6d5bac4e0>,
#  <matplotlib.lines.Line2D at 0x7fa6d5bac630>,
#  <matplotlib.lines.Line2D at 0x7fa6d5bac780>,
#  <matplotlib.lines.Line2D at 0x7fa6d5bac8d0>,
#  <matplotlib.lines.Line2D at 0x7fa6d5baca20>,
#  <matplotlib.lines.Line2D at 0x7fa6d5bacb70>,
#  <matplotlib.lines.Line2D at 0x7fa6d5baccc0>,
#  <matplotlib.lines.Line2D at 0x7fa6d5bace10>,
#  <matplotlib.lines.Line2D at 0x7fa6d5bacf60>,
#  <matplotlib.lines.Line2D at 0x7fa6d5baf0f0>,
#  <matplotlib.lines.Line2D at 0x7fa6d5baf240>,
#  <matplotlib.lines.Line2D at 0x7fa6d5baf390>,
#  <matplotlib.lines.Line2D at 0x7fa6d5baf4e0>]

# %%
import numpy as np
p=[[1,0],[0,1]]
q=[[1,2],[3,4]]
a=np.outer(p,q)
print(a)
# Out:
# [[1 2 3 4]
#  [0 0 0 0]
#  [0 0 0 0]
#  [1 2 3 4]]

# %%
import numpy as np
from numpy import linalg as la
k=np.array([[1,2],[3,4]])
print(la.cond(k))
# Out:
# 14.933034373659268

# %%
a=np.arange(6).reshape(2,3)
r=np.trace(a)
print(r)
# Out:
# 4
