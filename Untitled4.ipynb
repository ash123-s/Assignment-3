# %% [markdown]
# <a href="https://colab.research.google.com/github/ash123-s/Assignment-3/blob/master/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
d=pd.read_csv(r"/mobile_cleaned-1549119762886.csv")
d
# Out:
#      sim_type  aperture  gpu_rank  ...  battery_capacity  processor_rank  is_liked
# 0           0        12        55  ...              2000             125         1
# 1           0         1        55  ...              2000             165         1
# 2           0         9        55  ...              2500             164         0
# 3           0         8        55  ...              3000             165         1
# 4           1         1        55  ...              3000             165         0
# ..        ...       ...       ...  ...               ...             ...       ...
# 104         3        10        14  ...              3410               8         1
# 105         0         5         3  ...              3600             101         1
# 106         3        10         6  ...              2750               1         1
# 107         3        10        12  ...              1810               7         1
# ...

# %%
import matplotlib.pyplot as plt
x = d["price"]
y= d["weight"]
plt.plot(x,y)

# %%
import numpy as np
p=[[1,0],[0,1]]
q=[[1,2],[3,4]]
a=np.outer(p,q)
print(a)
# Out:
# [[1 2 3 4]
#  [0 0 0 0]
#  [0 0 0 0]
#  [1 2 3 4]]

# %%
import numpy as np
from numpy import linalg as la
k=np.array([[1,2],[3,4]])
print(la.cond(k))
# Out:
# 14.933034373659268

# %%
a=np.arange(6).reshape(2,3)
r=np.trace(a)
print(r)
# Out:
# 4
